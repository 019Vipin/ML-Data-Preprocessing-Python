# %% [markdown]
# <a href="https://colab.research.google.com/github/019Vipin/ML-Data-Preprocessing-Python/blob/main/Numerical_Dataset_Pre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Collection & Pre-Processing

# %%
# loading the data from csv file to a pandas dataframe
diabetes_data = pd.read_csv('/content/diabetes.csv')

# %%
# first 5 rows of the dataframe
diabetes_data.head()

# %%
# number of rows & columns
diabetes_data.shape

# %%
diabetes_data.describe()

# %% [markdown]
# Separating Features and Target

# %%
X = diabetes_data.drop(columns='Outcome', axis =1)
Y = diabetes_data['Outcome']

# %%
print(X)

# %%
print(Y)

# %% [markdown]
# 0 --> Non - Diabetic
#
# 1 --> Diabetic
#
# Data Standardization

# %%
scaler = StandardScaler()

# %%
standardized_data = scaler.fit_transform(X)

# %%
print(standardized_data)

# %%
X = standardized_data

# %%
print(X)

# %%
print(Y)

# %% [markdown]
# Splitting the dataset into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
